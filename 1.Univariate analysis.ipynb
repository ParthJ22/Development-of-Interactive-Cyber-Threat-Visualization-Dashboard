# %%
# import libraries (data manipulation,data visualization and warnings)
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the 50_Startups.csv
df1 = pd.read_csv('50_Startups.csv')
df1
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
# Read the Cars93.csv
df2 = pd.read_csv('Cars93.csv')
df2
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %% [markdown]
# # 1.Continuous column  >> Check the distribution plot

# %% [markdown]
# ## Skewness

# %% [raw]
# >> It is a measure of symmetry/asymmetry of data distribution
# >> How much our probability distribution curve varies from normal distrubution curve

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# Postive skewness(Right skew) - Tail of distribution is longer towards right hand side (left side data is more)
# Negative skewness(Left skew) - Tail of distribution is longer towards left hand side  (right side data is more)
#
# -0.5 to +0.5 >> Symmetrical distribution
# -1 to -0.5 >> Negative skewed distribution
# -1 > skew  >> Highly negative skewed distribution (-1.2,-1.5)
#
# 0.5 to 1.0 >> Positive skewed distribution
# skew > 1.0 >> Highly positive skewed distribtion(1.3,1.6)
#
# # Ideally skew value should be zero

# %% [markdown]
# ## Function to check skew value mathematically

# %%
df[column_name].skew()   # Spread of data

# spread of data means which data is in less proportion, which data is in moderete proportion 
# and which data is in large proportion

# %% [markdown]
# ## 1.1 Distribution plot >> Visualization method

# %%
sns.distplot(df[column_name])  # syntax for distribution plot

In this plot we get density on y axis, density means which data is densely populated and
which data is sparsely populated.

# %%
# Distribution plot for the price column
sns.distplot(df2.Price)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# Find skewness of price column
df2.Price.skew()
# Out:
# 1.53308185621344

# %%
# Compare mean and median of RND column
df2.Price.mean()
# Out:
# 19.509677419354837

# %%
df2.Price.median()
# Out:
# 17.7

# %%
# Distribution plot for the passengers column

sns.distplot(df2.Passengers)
# Out:
# <AxesSubplot:xlabel='Passengers', ylabel='Density'>

# %%
# Find skewness of passengers column
df2.Passengers.skew()
# Out:
# 0.06251685389476273

# %%
# Compare mean and median of passengers column
df2.Passengers.mean()
# Out:
# 5.086021505376344

# %%
df2.Passengers.median()
# Out:
# 5.0

# %%
# Distribution plot for the RPM column
sns.distplot(df2.RPM)
# Out:
# <AxesSubplot:xlabel='RPM', ylabel='Density'>

# %%
# Find skewness of RPM column
df2.RPM.skew()
# Out:
# -0.25853268574387145

# %%
# Compare mean and median of RPM column
df2.RPM.mean()
# Out:
# 5280.645161290323

# %%
df2.RPM.median()
# Out:
# 5200.0

# %%
sns.distplot(df1.ADMIN)
# Out:
# <AxesSubplot:xlabel='ADMIN', ylabel='Density'>

# %%
df1.ADMIN.skew()
# Out:
# -0.4890248099671768

# %%
df1.ADMIN.mean()
# Out:
# 121344.63959999995

# %%
df1.ADMIN.median()
# Out:
# 122699.795

# %%
# Distribution plot for the id column
sns.distplot(df2.id)
# Out:
# <AxesSubplot:xlabel='id', ylabel='Density'>

# %%
df2.id.skew()
# Out:
# 0.0

# %%
# How to deal with skewness
1. Log transformation
2. Square root transformation
3. Cube root trasnformation
4. Reciprocal transformation

# %% [markdown]
# # Subplots

# %%
plt.figure(figsize=(15,10))

plt.subplot(Total no of rows,Total no of columns,subplot number)
sns.distplot(df[column_name])

# %%
# Make a subplot having 4 distribution plots of RND,MKT,ADMIN and PROFIT column

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.distplot(df1.RND)

plt.subplot(2,2,2)
sns.distplot(df1.MKT)

plt.subplot(2,2,3)
sns.distplot(df1.ADMIN)

plt.subplot(2,2,4)
sns.distplot(df1.PROFIT)
# Out:
# <AxesSubplot:xlabel='PROFIT', ylabel='Density'>

# %% [markdown]
# # 2.Categorical column

# %% [markdown]
# ## Countplot

# %%
sns.countplot(df[column_name])  # syntax for countplot

# %%
# Find value counts of STATE column
df1.STATE.value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: STATE, dtype: int64

# %%
# Plot countplot of STATE column (Visual representation of value counts)
sns.countplot(df1.STATE)
# Out:
# <AxesSubplot:xlabel='STATE', ylabel='count'>

# %%
# Find value counts of Type column
df2.Type.value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
# Plot countplot of Type column
sns.countplot(df2.Type)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
# plot a subplot of Price,Length,Type,AirBags,Origin,Weight,Width,Manufacturer,Horsepower column
plt.figure(figsize=(20,15))

plt.subplot(3,3,1)
sns.distplot(df2.Price)

plt.subplot(3,3,2)
sns.distplot(df2.Length)

plt.subplot(3,3,3)
sns.countplot(df2.Type)

plt.subplot(3,3,4)
sns.countplot(df2.AirBags)

plt.subplot(3,3,5)
sns.countplot(df2.Origin)

plt.subplot(3,3,6)
sns.distplot(df2.Weight)

plt.subplot(3,3,7)
sns.distplot(df2.Width)

plt.subplot(3,3,8)
sns.countplot(df2.Manufacturer)

plt.subplot(3,3,9)
sns.distplot(df2.Horsepower)
# Out:
# <AxesSubplot:xlabel='Horsepower', ylabel='Density'>
