# %%
# import libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the 50 startups.csv
df = pd.read_csv('50_Startups.csv')
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# # 1. Pairplot

# %%
# check the pairplot of 50 startups
sns.pairplot(df)

# %% [markdown]
# # 2. Correlation coefficient

# %%
# check the correlation coefficient of 50 startups
df.corr()
# Out:
#              RND     ADMIN       MKT    PROFIT
# RND     1.000000  0.241955  0.724248  0.972900
# ADMIN   0.241955  1.000000 -0.032154  0.200717
# MKT     0.724248 -0.032154  1.000000  0.747766
# PROFIT  0.972900  0.200717  0.747766  1.000000

# %% [markdown]
# # 3.Correlation matrix

# %%
sns.heatmap(df.corr(),annot=True)  # syntax for correlation matrix

# %%
# correlation matrix of 50 startups
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Scatterplot

# %%
# scatterplot of RND vs PROFIT
sns.scatterplot(df.RND,df.PROFIT)
# Out:
# <AxesSubplot:xlabel='RND', ylabel='PROFIT'>

# %%
# scatterplot of RND vs PROFIT with hue as STATE
sns.scatterplot(df.RND,df.PROFIT,hue=df.STATE)
# Out:
# <AxesSubplot:xlabel='RND', ylabel='PROFIT'>
